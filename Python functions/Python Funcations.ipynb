# %%
def am():
    print('Good Morning Python Team')

# %%
def am():
    print('Good Morning Python Team')
am()
# Out:
# Good Morning Python Team

# %%
def greet():
    print('wel come To ')
    print('hello world')

# %%
def greet():
    print('wel come To ')
    print('hello world')
greet()
# Out:
# wel come To
# hello world

# %%
def greet():
    print('wel come To ')
    print('hello world')
greet()    

def greet():
    print('wel come To ')
    print('hello world')
greet()    

def greet():
    print('wel come To ')
    print('hello world')
greet()
# Out:
# wel come To
# hello world
# wel come To
# hello world
# wel come To
# hello world

# %%
def greet():
    print('hello good morning data science team')
greet()   

greet()  

greet()  

greet()
# Out:
# hello good morning data science team
# hello good morning data science team
# hello good morning data science team
# hello good morning data science team

# %%
def add(x,y):
    c = x+y
    print(c)

add(5,6,7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2     c = x+y
#       3     print(c)
# ----> 5 add(5,6,7,8)
#
# TypeError: add() takes 2 positional arguments but 4 were given

# %%
def add(x,y):
    c = x+y
    print(c)

add(5,6)
# Out:
# 11

# %%
def add(x,y,z):
    c=x+y+z+m
    print(c)

add(1,4,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       2     c=x+y+z+m
#       3     print(c)
# ----> 5 add(1,4,5)
#
# Cell In[15], line 2, in add(x, y, z)
#       1 def add(x,y,z):
# ----> 2     c=x+y+z+m
#       3     print(c)
#
# NameError: name 'm' is not defined

# %%
def add(x,y,z,m):
    c=x+y+z+m
    print(c)

add(1,4,5,6)
# Out:
# 16

# %%
def greet():
    print('hello')
    print('good morning')

greet()
# Out:
# hello
# good morning

# %%
def add(x,y):
    c=x+y
    print(c)

add(5,6)
# Out:
# 11

# %%
def greet():
    print('hello')
    print('good morning')

greet()

def add(x,y):
    c=x+y
    print(c)

add(5,6)
# Out:
# hello
# good morning
# 11

# %%
def greet():
    print('hello')
    print('good morning')

def add(x,y):
    c=x+y
    print(c)

add(5,6)
greet()
# Out:
# 11
# hello
# good morning

# %%
def greet():
    print('hello')
    print('good morning')

def add(x,y):
    c=x+y
    print(c)

def sub(x,y):
    d = x-y
    print(d)

greet()
add(5,6)
sub(10,2)
# Out:
# hello
# good morning
# 11
# 8

# %%
def add_sub(x,y):
    c = x+y
    d = x-y
    print(c)
    print(d)

add_sub(10,5)
# Out:
# 15
# 5

# %%
def add_sub(x,y):
    c = x+y
    d = x-y
    return c,d

add_sub(10,5)
# Out:
# (15, 5)

# %%
def add_sub(x,y):
    c = x+y
    d = x-y
    return c, d

result = add_sub(5,4)

print(result)
# Out:
# (9, 1)

# %%
def add_sub(x,y):
    c = x+y
    d = x-y
    return c, d

result1,result2 = add_sub(5,4)

print(result1,result2)
# Out:
# 9 1

# %%
def add(x,y):
    c = x+y
    print(c)

add(5,6)
# Out:
# 11

# %% [markdown]
# # FORMAL ARGUMENT & ACTUAL ARGUMENT

# %%
def person(name,age):
    print(name)
    print(age)

person('nit',23,24)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit',23,24)
#
# TypeError: person() takes 2 positional arguments but 3 were given

# %%
def person(name,age):
    print(name)
    print(age)

person('nit',23,)
# Out:
# nit
# 23

# %%
def person(name,age):
    print(name)
    print(age+1)

person(age1=23,name='nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 5
#       2     print(name)
#       3     print(age+1)
# ----> 5 person(age1=23,name='nit')
#
# TypeError: person() got an unexpected keyword argument 'age1'

# %%
def person(name,age1):
    print(name)
    print(age1+1)

person(age1=23,name='nit')
# Out:
# nit
# 24

# %%
def person(name,age,city):
    print(name)
    print(age+1)
    print(city)

person(age=23,name='nit',city='hyd')
# Out:
# nit
# 24
# hyd

# %%
def person(name, age=18):
    print(name)
    print(age)

person('nit',24)
# Out:
# nit
# 24
