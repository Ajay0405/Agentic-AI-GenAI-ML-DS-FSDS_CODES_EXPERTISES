# %% [markdown]
# # Excepitonal handling in python

# %%
a=5
b=2
print(a/b)
print('bye')
# Out:
# 2.5
# bye

# %%
c=5
d=0
print(d/c)
print('bye')
# Out:
# 0.0
# bye

# %%
c=5
d=0
print('bye')
print(d/c)
# Out:
# bye
# 0.0

# %%
c=5
d=0
print('bye')
print(c/d)
# Out:
# bye
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 d=0
#       3 print('bye')
# ----> 4 print(c/d)
#
# ZeroDivisionError: division by zero

# %%
c=5
d=0
print(c/d)
print('bye')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 c=5
#       2 d=0
# ----> 3 print(c/d)
#       4 print('bye')
#
# ZeroDivisionError: division by zero

# %%
c=3
d=0
try:
    print(c/d)
except Exception:
    print('hey you cannot divide number by zero')
print('bye')
# Out:
# hey you cannot divide number by zero
# bye

# %%
c=3
d=0
try:
    print(c/d)
except Exception as e:
    print('hey you cannot divide number by zero:',e)
print('bye')
# Out:
# hey you cannot divide number by zero: division by zero
# bye

# %%
c=3
d=0
try:
    print(d/c)
except Exception:
    print('hey you cannot divide number by zero')
print('bye')
# Out:
# 0.0
# bye

# %%
c = 3
d = 3

try:
    print('resource open')
    print(c/d)
    print('resource closed')
except Exception as e:
    print('hey you cannot divide Number by zero',':',e)
# Out:
# resource open
# 1.0
# resource closed

# %%
c = 3
d = 0


try:
    print('resource open')
    print(c/d)
    print('resource closed')

except Exception as e :
    print('hey you cannot divide Number zero',':',e)
# Out:
# resource open
# hey you cannot divide Number zero : division by zero

# %%
c = 3 
d = 0
try:
    print('resource open')
    print(c/d)

except Exception as e :
    print('hey you cannot divide Number by zero',':',e)
    print('resource closed')
# Out:
# resource open
# hey you cannot divide Number by zero : division by zero
# resource closed

# %%
c = 3
d = 3

try:
    print('resource open')
    print(c/d)

except Exception as e :
    print('hey you cannot divide Number by zero', e)
    print('resource closed')
# Out:
# resource open
# 1.0
